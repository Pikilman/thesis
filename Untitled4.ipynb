# %% [markdown]
# <a href="https://colab.research.google.com/github/Pikilman/thesis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# QUERY GENERATION
## Cloning G. Penha repository to get access to disentangled_information_needs and other query generation functions.

# %%
# !git clone https://github.com/Guzpenha/query_variation_generators.git
# Out:
# fatal: destination path 'query_variation_generators' already exists and is not an empty directory.

# %% [markdown]
# #QUERY SUMMARY
# Counting valid queries and their transformation type, displaying in table for each set of annoted queries. Author queries are available in G. Penha repository as .csv files at '/content/query_variation_generators/data/variations_trec2019_labeled.csv' and '/content/query_variation_generators/data/variations_antique_labeled.csv'

# %%
# Importing necessary dataframe and expression counting functions
import pandas as pd
import re
#reading in files of annoted query variations from Penha, G et al.
file_n_antique= "/content/query_variation_generators/data/variations_antique_labeled.csv"
file_n_trec = "/content/query_variation_generators/data/variations_trec2019_labeled.csv"
query_variations_trec = pd.read_csv(file_n_trec)
query_variations_antiques = pd.read_csv(file_n_antique)
#Counting variations for methods and variation type for TREC2019 labelled set.
query_variations_trec["query"] = query_variations_trec.apply(lambda r, re=re: re.sub('[\W_]', ' ',  r['original_query'].lower()), axis=1)
query_variations_trec["variation"] = query_variations_trec.apply(lambda r, re=re: re.sub('[\W_]', ' ',  r['variation'].lower()), axis=1)
query_variations_trec["variation"] = query_variations_trec.apply(lambda r: r['query'] if r['variation'].strip() == "" else r['variation'], axis=1)
query_variations_trec['qid'] = query_variations_trec['q_id'].astype(str)
#Counting variations for methods and variation type for ANTIQUE labelled set.
query_variations_antiques["query"] = query_variations_antiques.apply(lambda r, re=re: re.sub('[\W_]', ' ',  r['original_query'].lower()), axis=1)
query_variations_antiques["variation"] = query_variations_antiques.apply(lambda r, re=re: re.sub('[\W_]', ' ',  r['variation'].lower()), axis=1)
query_variations_antiques["variation"] = query_variations_antiques.apply(lambda r: r['query'] if r['variation'].strip() == "" else r['variation'], axis=1)
query_variations_antiques['qid'] = query_variations_antiques['q_id'].astype(str)

# %%
#Displaying Dataframe table for TREC2019 variation counts as performed by Penha, G et al.
query_variations_trec = query_variations_trec[(query_variations_trec["valid"])].groupby(["transformation_type","method"]).count().reset_index()[["transformation_type", "method", "dataset"]]
query_variations_trec.columns = ["transformation_type", "method", "count"]
query_variations_trec
# Out:
#   transformation_type                                             method  \
# 0          mispelling                   WordSwapNeighboringCharacterSwap
# 1          mispelling                                     WordSwapQWERTY
# 2          mispelling                WordSwapRandomCharacterSubstitution
# 3          naturality                  naturality_by_removing_stop_words
# 4          naturality  summarization_with_t5-base_from_description_to...
# 5            ordering                                WordInnerSwapRandom
# 6          paraphrase                 back_translation_pivot_language_de
# 7          paraphrase                      ramsrigouthamg/t5_paraphraser
# 8             synonym                                  WordSwapEmbedding
# 9             synonym                                    WordSwapWordNet
#
#    count
# 0     43
# 1     42
# 2     42
# 3     37
# 4     35
# 5     43
# 6     23
# 7     26
# 8     27
# 9     16

# %% [markdown]
# Displaying DATAFRAME table for ANTIQUE dataset query variation counts as performed by Penha, G et al.

# %%
#Displaying Dataframe table for ANTIQUE variation counts as performed by Penha, G et al.
query_variations_antiques = query_variations_antiques[(query_variations_antiques["valid"])].groupby(["transformation_type","method"]).count().reset_index()[["transformation_type", "method", "dataset"]]
query_variations_antiques.columns = ["transformation_type", "method", "count"]
query_variations_antiques
# Out:
#   transformation_type                                             method  \
# 0          mispelling                   WordSwapNeighboringCharacterSwap
# 1          mispelling                                     WordSwapQWERTY
# 2          mispelling                WordSwapRandomCharacterSubstitution
# 3          naturality                  naturality_by_removing_stop_words
# 4          naturality  summarization_with_t5-base_from_description_to...
# 5            ordering                                WordInnerSwapRandom
# 6          paraphrase                 back_translation_pivot_language_de
# 7          paraphrase                      ramsrigouthamg/t5_paraphraser
# 8             synonym                                  WordSwapEmbedding
# 9             synonym                                    WordSwapWordNet
#
#    count
# 0    199
# 1    182
# 2    197
# 3    199
# 4    136
# 5    200
# 6     93
# 7    105
# 8    124
# 9     71

# %% [markdown]
# These .csv files contain the same original queries and their respective variations used in the authors' paper. To generate the provided queries methods provided by the authors can be used.
# ## Generating Query Variations
# ##### Necessarily need to access the authors' github repository to make use of the authors' query variation generators. Additional requirements are also imported and installed. The methods implemented by Penha, G et al. can then be replicated.

# %% [markdown]
# Launching a python virtual environment and installing necessary packages

# %%
# !git clone https://github.com/Guzpenha/query_variation_generators.git
# %cd /content/query_variation_generators 
# !apt-get install python3-venv
# !python3 -m venv env
# !source env/bin/activate
# !pip install -e .
# !pip install torch transformers IPython pandas ir_datasets textattack protobuf python-terrier trectools
# !pip install git+https://github.com/Georgetown-IR-Lab/OpenNIR git+https://github.com/terrierteam/pyterrier_doc2query.git
# !pip install git+https://github.com/terrierteam/pyterrier_t5
# Out:
# fatal: destination path 'query_variation_generators' already exists and is not an empty directory.
# /content/query_variation_generators
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-venv is already the newest version (3.8.2-0ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Error: Command '['/content/query_variation_generators/env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: env/bin/activate: No such file or directory
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/query_variation_generators
#   Preparing metadata (setup.py) ... done
# Installing collected packages: disentangled-information-needs
#   Attempting uninstall: disentangled-information-needs
#     Found existing installation: disentangled-information-needs 0.0.1
#     Uninstalling disentangled-information-needs-0.0.1:
#       Successfully uninstalled disentangled-information-needs-0.0.1
#   Running setup.py develop for disentangled-information-needs
# Successfully installed disentangled-information-needs-0.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ir_datasets in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: textattack in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (3.20.2)
# Requirement already satisfied: python-terrier in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: trectools in /usr/local/lib/python3.10/dist-packages (0.0.49)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from IPython) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.11.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.9.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.6)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (3.2.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.9)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.2)
# Requirement already satisfied: bert-score>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.3.13)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from textattack) (0.6.2)
# Requirement already satisfied: flair in /usr/local/lib/python3.10/dist-packages (from textattack) (0.12.2)
# Requirement already satisfied: language-tool-python in /usr/local/lib/python3.10/dist-packages (from textattack) (2.7.1)
# Requirement already satisfied: lemminflect in /usr/local/lib/python3.10/dist-packages (from textattack) (0.2.3)
# Requirement already satisfied: lru-dict in /usr/local/lib/python3.10/dist-packages (from textattack) (1.1.8)
# Requirement already satisfied: datasets==2.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (2.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from textattack) (3.8.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.10.1)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from textattack) (3.1.10)
# Requirement already satisfied: word2number in /usr/local/lib/python3.10/dist-packages (from textattack) (1.1)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from textattack) (0.5.12)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textattack) (9.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.7.1)
# Requirement already satisfied: pinyin==0.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.4.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from textattack) (0.42.1)
# Requirement already satisfied: OpenHowNet in /usr/local/lib/python3.10/dist-packages (from textattack) (2.0)
# Requirement already satisfied: pycld2 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.41)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (8.0.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (9.0.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.3.5.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.18.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.13)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.0)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.13.5)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.3.1)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: sarge>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from trectools) (0.1.7.post1)
# Requirement already satisfied: bs4>=0.0.0.1 in /usr/local/lib/python3.10/dist-packages (from trectools) (0.0.1)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.10/dist-packages (from trectools) (3.7.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets) (2.4.1)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->trectools) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.6)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pyjnius>=1.4.2->python-terrier) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier) (3.1.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets) (1.0.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.3.1)
# Requirement already satisfied: segtok>=1.5.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.5.11)
# Requirement already satisfied: mpld3==0.3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.3)
# Requirement already satisfied: sqlitedict>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (2.1.0)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.7)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.26.132)
# Requirement already satisfied: bpemb>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.8.10)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.0.9)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (6.1.1)
# Requirement already satisfied: janome in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.4.2)
# Requirement already satisfied: gdown==4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.4.0)
# Requirement already satisfied: conllu>=4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.5.2)
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.5.8)
# Requirement already satisfied: pptree in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (3.1)
# Requirement already satisfied: pytorch-revgrad in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: anytree in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack) (2.8.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair->textattack) (0.1.99)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.3.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.8.0->flair->textattack) (6.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.10.9.7)
# Requirement already satisfied: botocore<1.30.0,>=1.29.132 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (1.29.132)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (0.6.1)
# Requirement already satisfied: accelerate>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->transformers) (5.9.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/Georgetown-IR-Lab/OpenNIR
#   Cloning https://github.com/Georgetown-IR-Lab/OpenNIR to /tmp/pip-req-build-xf7w0uqp
#   Running command git clone --filter=blob:none --quiet https://github.com/Georgetown-IR-Lab/OpenNIR /tmp/pip-req-build-xf7w0uqp
#   Resolved https://github.com/Georgetown-IR-Lab/OpenNIR to commit 88a4679372f471a04d284a99404ffce2b7a1dc49
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/terrierteam/pyterrier_doc2query.git
#   Cloning https://github.com/terrierteam/pyterrier_doc2query.git to /tmp/pip-req-build-_kchcd4g
#   Running command git clone --filter=blob:none --quiet https://github.com/terrierteam/pyterrier_doc2query.git /tmp/pip-req-build-_kchcd4g
#   Resolved https://github.com/terrierteam/pyterrier_doc2query.git to commit 3449bcaf0727721d8d77c2524f0dc77dbbb77da0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (2.0.0+cu118)
# Requirement already satisfied: pytorch-pretrained-bert==0.6.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.6.1)
# Requirement already satisfied: pytorch-transformers==1.1.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.1.0)
# Requirement already satisfied: tokenizers>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.13.3)
# Requirement already satisfied: transformers>=4.3.3 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (4.29.0)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (4.65.0)
# Requirement already satisfied: colorlog==4.0.2 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (4.0.2)
# Requirement already satisfied: terminaltables>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (3.1.10)
# Requirement already satisfied: matplotlib>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (3.7.1)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.12.2)
# Requirement already satisfied: python-ternary>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.0.8)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (4.11.2)
# Requirement already satisfied: html5lib>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.1)
# Requirement already satisfied: Unidecode>=1.0.22 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.3.6)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (3.8.1)
# Requirement already satisfied: sqlitedict>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (2.1.0)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.5.5)
# Requirement already satisfied: gensim>=3.7.3 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (4.3.1)
# Requirement already satisfied: Cython>=0.29.2 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.29.34)
# Requirement already satisfied: pyjnius>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.4.2)
# Requirement already satisfied: ir_datasets>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.5.4)
# Requirement already satisfied: ir_measures>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (0.3.1)
# Requirement already satisfied: pytools>=2018.5.2 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (2022.1.14)
# Requirement already satisfied: cached-property>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from OpenNIR==0.1.0) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.22.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.26.132)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.27.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2022.10.31)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from pytorch-transformers==1.1.0->OpenNIR==0.1.0) (0.1.99)
# Requirement already satisfied: python-terrier>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pyterrier-doc2query==0.0.1) (0.9.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyterrier-doc2query==0.0.1) (1.5.3)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.10/dist-packages (from pyterrier-doc2query==0.0.1) (3.1.31)
# Requirement already satisfied: npids in /usr/local/lib/python3.10/dist-packages (from pyterrier-doc2query==0.0.1) (0.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.9.3->OpenNIR==0.1.0) (2.4.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (6.3.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (0.5.1)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (4.9.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (6.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.6)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.2.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.9)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir_measures>=0.2.1->OpenNIR==0.1.0) (1.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (8.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (1.2.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (3.2)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (0.5.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.2.13)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (0.2.3)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.4.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (9.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (0.13.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (0.3.5.1)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.9.3)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (4.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyterrier-doc2query==0.0.1) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->OpenNIR==0.1.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->OpenNIR==0.1.0) (16.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (0.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython->pyterrier-doc2query==0.0.1) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython->pyterrier-doc2query==0.0.1) (5.0.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers>=4.3.3->OpenNIR==0.1.0) (2023.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (3.4)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.2.0->OpenNIR==0.1.0) (1.0.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.132 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.29.132)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (0.6.1)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (2.1.2)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-doc2query==0.0.1) (0.5.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.1->OpenNIR==0.1.0) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/terrierteam/pyterrier_t5
#   Cloning https://github.com/terrierteam/pyterrier_t5 to /tmp/pip-req-build-kjyxppgr
#   Running command git clone --filter=blob:none --quiet https://github.com/terrierteam/pyterrier_t5 /tmp/pip-req-build-kjyxppgr
#   Resolved https://github.com/terrierteam/pyterrier_t5 to commit 1b5e1670d602977c504eca85ce8c6cd22ce34b99
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-terrier>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (0.9.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (1.5.3)
# Requirement already satisfied: transformers>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (4.29.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (2.0.0+cu118)
# Requirement already satisfied: sentencepiece>=0.1.95 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.22.4)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.65.0)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.4.2)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.13)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.0)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.4.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (9.1.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.13.5)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.5.1)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.9.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.13.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyterrier-t5==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyterrier-t5==0.0.1) (2022.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->pyterrier-t5==0.0.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->pyterrier-t5==0.0.1) (16.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers>=4.0.0->pyterrier-t5==0.0.1) (2023.4.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.11.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.9.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.6)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.9)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir-measures>=0.3.1->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.12)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pyjnius>=1.4.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.4)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.2)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pyterrier-t5==0.0.1) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.4.1)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.0)

# %% [markdown]
# Generating Query Variations

# %%
from disentangled_information_needs.transformations.synonym import SynonymActions
from disentangled_information_needs.transformations.paraphrase import ParaphraseActions
from disentangled_information_needs.transformations.naturality import NaturalityActions
from disentangled_information_needs.transformations.mispelling import MispellingActions
from disentangled_information_needs.transformations.ordering import OrderingActions

import pandas as pd
import ir_datasets
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# Setting training parameters for desc2t5 query variations and paraphrasing tasks

# %%
#task = 'car/v1.5/train/fold0'
task ='antique/train/split200-valid'
out_dir = "."
sample = 10

# %% [markdown]
# Using 'ir_datasets' package to access data set and 'disentangled_information_needs' to perform appropriate transformations

# %%
dataset = ir_datasets.load(task)
queries = [t[1].lower() for t in dataset.queries_iter()]
q_ids = [t[0] for t in dataset.queries_iter()]

pa = ParaphraseActions(queries, q_ids, out_dir)
transformed_queries_paraphrase_models = pa.seq2seq_paraphrase(sample=sample)
transformed_queries_back_translation = pa.back_translation_paraphrase(sample=sample)

na = NaturalityActions(queries, q_ids)
#transformed_queries_trec_desc_to_title = na.naturality_by_trec_desc_to_title(model_path="", sample=sample)
transformed_queries_stop_word_removal = na.remove_stop_words(sample=sample)
transformed_queries_stop_word_and_stratified_removal = na.remove_stop_words_and_stratify_by_len(sample=sample)
transformed_queries_summarizer = na.naturality_by_summarization(sample=sample)

sa = SynonymActions(queries, q_ids)
transformed_queries_syn = sa.adversarial_synonym_replacement(sample=sample)

oa = OrderingActions(queries, q_ids)
transformed_queries_shuffled_order = oa.shuffle_word_order(sample=sample)

ma = MispellingActions(queries, q_ids)
transformed_queries_mispelling = ma.mispelling_chars(sample=sample)


transformed_queries =  transformed_queries_mispelling +\
  transformed_queries_shuffled_order  +\
  transformed_queries_syn + \
  transformed_queries_paraphrase_models + \
  transformed_queries_back_translation +  \
  transformed_queries_stop_word_removal +  \
  transformed_queries_summarizer# #+ \
  #transformed_queries_trec_desc_to_title

transformed_queries = pd.DataFrame(transformed_queries, columns = ["q_id", "original_query", "variation", "method", "transformation_type"])
# Out:
#   0%|          | 0/13 [00:09<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (200) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   5%|▌         | 10/200 [00:08<02:47,  1.14it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
#   5%|▌         | 10/200 [00:00<00:00, 76398.98it/s]
#   5%|▌         | 10/200 [00:00<00:00, 43284.87it/s]
#   0%|          | 0/13 [00:01<?, ?it/s]
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#   5%|▌         | 10/200 [00:13<04:20,  1.37s/it]
#   5%|▌         | 10/200 [00:00<00:00, 470.84it/s]
#   5%|▌         | 10/200 [00:00<00:00, 377.01it/s]

# %%
transformed_queries
# Out:
#         q_id                                     original_query  \
# 0    1907320                        how do i get college money?
# 1    1907320                        how do i get college money?
# 2    1907320                        how do i get college money?
# 3    3884772            how about a bumper sticker thats says:?
# 4    3884772            how about a bumper sticker thats says:?
# ..       ...                                                ...
# 115  3752394  why haven't muslims protested the terrorism by...
# 116  1485589                                     how sun rises?
# 117   844617                       how are dna and rna similar?
# 118  4042061               why do parakeets bounce up and down?
# 119  1158088                why my neighbor's dog doesn't bark?
#
#                                    variation  \
# 0                how do i get college moeny?
# 1                how do i Qet college money?
# 2                how do i get collegf money?
# 3    how about a bumper sticker thast says:?
# 4    how about a bumper sticker tWats says:?
# ..                                       ...
# 115                          why haven't mus
# 116                              sun rises??
# 117                                dna and r
# 118                        Warum do parakeet
# 119                   a neighbor's dog doesn
#
#                                   method transformation_type
# 0       WordSwapNeighboringCharacterSwap          mispelling
# 1    WordSwapRandomCharacterSubstitution          mispelling
# 2                         WordSwapQWERTY          mispelling
# 3       WordSwapNeighboringCharacterSwap          mispelling
# 4    WordSwapRandomCharacterSubstitution          mispelling
# ..                                   ...                 ...
# 115           summarization_with_t5-base          naturality
# 116           summarization_with_t5-base          naturality
# 117           summarization_with_t5-base          naturality
# 118           summarization_with_t5-base          naturality
# 119           summarization_with_t5-base          naturality
#
# [120 rows x 5 columns]

# %% [markdown]
# ###Downloading manually annoted author query variation generations
# Reading and downloading ccessing author provided manuallly quality checked query variations
